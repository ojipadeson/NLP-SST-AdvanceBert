# %%
# !git clone https://*github_username*:*personal_token*@github.com/*github_username*/SA_big

# %% [markdown]
# Example: ```!git clone https://ojipadeson:ThisismyTOKEN@github.com/ojipadeson/SA_big```

# %%
# !ls

# %%
# %cd SA_big

# %% [markdown]
# # **First, run model with pure train data(precise binary)**

# %%
# !python run_Bert_model.py -s

# %%
# !python run_Albert_model.py -s

# %%
# !python run_Roberta_model.py -s

# %%
# !python run_Xlnet_model.py -s

# %% [markdown]
# # **Next, we run model with pj train data.**

# %%
# !python run_Bert_model.py -p -s

# %%
# !python run_Albert_model.py -p -s

# %%
# !python run_Roberta_model.py -p -s

# %%
# !python run_Xlnet_model.py -p -s
