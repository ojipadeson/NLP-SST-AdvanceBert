# %%
# !git clone https://ojipadeson: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@github.com/ojipadeson/SA_big

# %%
# !ls

# %%
# %cd SA_big

# %% [markdown]
# # **First, run model with pure train data(precise binary)**

# %%
# !python run_Bert_model.py

# %%
# !python run_Albert_model.py

# %%
# !python run_Roberta_model.py

# %%
# !python run_Xlnet_model.py

# %% [markdown]
# # **Next, we run model with pj train data.**

# %%
# !python run_Bert_model.py -p

# %%
# !python run_Albert_model.py -p

# %%
# !python run_Roberta_model.py -p

# %%
# !python run_Xlnet_model.py -p
